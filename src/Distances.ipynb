# %% [markdown]
# # Create a graph of all the nodes found suspected to be charities

# %%
#Imports
import pandas as pd

#spark
import findspark
findspark.init('/opt/spark/spark-2.3.2-bin-hadoop2.7/')

from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.functions import min
from pyspark.sql.functions import udf
from pyspark.sql.functions import split
from pyspark.sql.functions import explode

from pyspark.sql.types import StringType
from pyspark.sql.types import TimestampType

from pyspark.sql import SparkSession
from pyspark import SparkContext

spark = SparkSession.builder.getOrCreate()

# %%
#Constants



def get_match_file(leak, charity):
    return '../generated/matches/' + leak + '_' + charity + '_matches.csv'

# %%
get_match_file('panama', 'wikipedia')
# Out:
# '../generated/matches/panama_wikipedia_matches.csv'

# %%
#Load matches
panama_wiki_matches = spark.read.csv(get_match_file('panama', 'wikipedia'), index_col=0, header=True)
panama_ingo_matches = spark.read.csv(get_match_file('panama', 'INGO'), index_col=0, header=True)
panama_forbes_matches = spark.read.csv(get_match_file('panama', 'forbes'), index_col=0, header=True)

#Load edges
edges = spark.read.csv('../data/panama/panama_papers.edges.csv', header=True)
# Out:
# /home/sabrina/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
#         START_ID                TYPE    END_ID  \
# 0       10000035  registered_address  14095990
# 1       10000044  registered_address  14091035
# 2       10000055  registered_address  14095990
# 3       10000064  registered_address  14091429
# 4       10000089  registered_address  14098253
# 5       10000091  registered_address  14091429
# 6       10000098  registered_address  14099188
# 7       10000105  registered_address  14095990
# 8       10000109  registered_address  14091429
# 9       10000297  registered_address  14095271
# 10      10000464  registered_address  14099155
# 11      10000507  registered_address  14094124
# 12      10000580  registered_address  14097397
# 13      10000581  registered_address  14092297
# 14      10000584  registered_address  14094414
# 15      10000635  registered_address  14095990
# 16      10000644  registered_address  14096319
# 17      10000670  registered_address  14108530
# 18      10000733  registered_address  14092130
# ...

# %%
#Filter edges for found nodes
found_nodes = edges.filter()

# %%
#map nodes and edges
