# %% [markdown]
# # Scraping Data about Charities from the internet

# %% [markdown]
# ## Potential Sources:
#
# * https://en.wikipedia.org/wiki/Category:International_charities
# * https://en.wikipedia.org/wiki/List_of_charitable_foundations
# * https://nccs-data.urban.org/data.php?ds=core
# * https://www.forbes.com/sites/williampbarrett/2016/12/14/the-largest-u-s-charities-for-2016/#5ca92a8d4abb

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
charity = pd.read_csv('../../data/wikipedia/nccs.core2015pc.csv')
# Out:
# /home/sabrina/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (141,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
charity.columns.tolist()
names = pd.DataFrame(charity['NAME'].unique(), columns=['Names'])
names
# Out:
#                                                    Names
# 0      AMERICAN LEGION AUXILIARY 178 DANIEL E LAMBERT...
# 1           AMERICAN LEGION POST 0019 THOMAS W COLE POST
# 2              AMERICAN LEGION POST 0005 BOURQUE LANIGAN
# 3                       AMERICAN LEGION 22 DEPT OF MAINE
# 4      ANCIENT FREE AND ACCEPTED MASONS OF MAINE GRAN...
# 5                        MAINE STATE CHAMBER OF COMMERCE
# 6                                   AUGUSTA COUNTRY CLUB
# 7                      BANGOR REGION CHAMBER OF COMMERCE
# 8      BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE...
# 9      BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE...
# 10     BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE...
# 11     BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE...
# 12     BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE...
# 13         BETA THETA PI FRATERNITY 161 BETA ETA CHAPTER
# 14                BIDDEFORD SACO CHAMBER OF COMMERCE INC
# ...

# %%
print(names[names['Names'].str.contains('GATES', na=False)]['Names'].tolist())
# Out:
# ['ASSOCIATION OF SURROGATES SUPREME COURT REPORTERS WITHIN THE CITY OF', 'GATES CHILI CHAMBER OF COMMERCE INC', 'PENNSYLVANIA AGGREGATES AND CONCRETE ASSOCIATION', 'GREEN GATES CEMETERY ASSOCIATION INC', 'INDIANA MINERAL AGGREGATES', 'WHITE GATES SKEET CLUB', 'MICHIGAN AGGREGATES ASSOCIATION INC', 'NEBRASKA CONCRETE AND AGGREGATES ASSOCIATION', 'TEXAS AGGREGATES AND CONCRETE ASSOCIATION', 'NORTH CAROLINA AGGREGATES ASSOCIATION', 'CONCRETE AND AGGREGATES ASSOCIATION OF LOUISIANA INC', 'OKLAHOMA AGGREGATES ASSOCIATION', 'GATESVILLE COUNTRY CLUB STRAWS MILL RD S GATESVILLE', 'FORT GATES WATER SUPPLY CORP', 'WASHINGTON AGGREGATES AND CONCRETE ASSN', 'CROSSGATES SWIM CLUB', 'GATES JONES MUTUAL WATER COMPANY']
