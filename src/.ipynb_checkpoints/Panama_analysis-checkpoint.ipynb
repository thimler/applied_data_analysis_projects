# %%
# Imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import math
import re
import numpy as np

# %%
DATA_FOLDER = '../data'
PANAMA_DATA_FOLDER = DATA_FOLDER + '/panama/'
WIKIPEDIA_DATA_FOLDER = DATA_FOLDER + '/wikipedia/'

# %%
# Loading and creation of dataframes
pp_edges = pd.read_csv('../data/panama/' + 'panama_papers.edges.csv', sep=',')
pp_adress = pd.read_csv('../data/panama/' +  'panama_papers.nodes.address.csv', sep=',')
pp_entity = pd.read_csv('../data/panama/' + 'panama_papers.nodes.entity.csv', sep=',')
pp_intermediary = pd.read_csv('../data/panama/' + 'panama_papers.nodes.intermediary.csv', sep=',')
pp_officer = pd.read_csv('../data/panama/' + 'panama_papers.nodes.officer.csv', sep=',')
# Out:
# /home/sabrina/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/sabrina/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pp_entity
# Out:
#          node_id                                               name  \
# 0       10000001           TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1       10000002        NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2       10000003                                 HOTFOCUS CO., LTD.
# 3       10000004                    SKY-BLUE GIFTS & TOYS CO., LTD.
# 4       10000005               FORTUNEMAKER INVESTMENTS CORPORATION
# 5       10000006                               8808 HOLDING LIMITED
# 6       10000007                           KENT DEVELOPMENT LIMITED
# 7       10000008                                BONUS TRADE LIMITED
# 8       10000009                                     AMARANDAN LTD.
# 9       10000010                                   NEW IDEA LIMITED
# 10      10000011                                 HUGH POWER LIMITED
# 11      10000012                             ULTIMATE GROUP LIMITED
# 12      10000013                              VICTORY GROUP LIMITED
# ...
