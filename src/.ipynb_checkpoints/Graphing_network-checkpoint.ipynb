# %% [markdown]
# # Graphs
#
# Using the previously collected data detailing how matches connect to the rest of the leaked information, we can create graphs and see the degree of interconnectivity between the matches.

# %%
#imports

import json
import itertools
import collections
import http_server

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from operator import itemgetter
from community import community_louvain
from networkx.readwrite import json_graph
from networkx.algorithms.community.centrality import girvan_newman

# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We only use degree 1, as larger degrees resulted in unmanagably large graphs. But distance 1 is quite good enough for our purposes.

# %%
#Global variables 

DEGREE = 1

DEGREE_FILE = '../generated/map/degree_' + str(DEGREE) +'/'

def get_graph_elem_file(elem_type, leak):
    return DEGREE_FILE + leak + '_' + elem_type + '.csv'

# %% [markdown]
# ### Create the graphs
#
# Note that as some of the graphs have still very many nodes, we can choose to filter these down to only those connected to more than one node (unless a node is a match -- we still want to know who is not connected to anyone).
#
# Note the special attention drawn to the "bahamas" leak, which has a slightly different schema.

# %%
def remove_loners(full_df):
    
    '''Removes nodes with fewer than 2 connections who are not matches'''
    
    node_counts = full_df['START_ID'].append(full_df['END_ID']).value_counts()

    ids_to_remove = []

    for index, row in full_df.iterrows():
        start_id = row['START_ID']
        end_id = row['END_ID']

        if (row['match_x'] == False and node_counts[start_id] < 2) or (row['match_y'] == False and node_counts[end_id] < 2):
            ids_to_remove.append(index)
    
    return full_df.drop(full_df.index[ids_to_remove]).reset_index(drop=True)

def graph_leak_matches(leak, dense=False):
    
    '''Creates graphs of matches found in a given leak'''
    
    bahamas = (leak == 'bahamas')

    node_id = '0'
    name_index = '1'

    if bahamas:
        node_id = '4' 
        name_index = '7'

    plt.rcParams["figure.figsize"] = (23,23)

    
    #Load the data
    nodes = pd.read_csv(get_graph_elem_file('nodes', leak), index_col=0)\
                                                            .reset_index(drop=True)[[node_id, name_index, 'Match']]

    nodes.rename(columns={node_id:'node_id', name_index:'name', 'Match':'match'}, inplace=True)
    nodes['id'] = nodes.index
    
    edges = pd.read_csv(get_graph_elem_file('edges', leak), index_col=0).reset_index(drop=True)[['START_ID', 'END_ID']]
    #edges.rename(columns={index:'index_start'})
    
    #Format the data as a set of edges with information about the nodes
    full_df = pd.merge(nodes, edges, left_on='node_id', right_on='START_ID')
    full_df = pd.merge(full_df, nodes, left_on='END_ID', right_on='node_id').drop(['node_id_x', 'node_id_y'], axis=1)
    
    #filter too large graphs if told so
    if dense:
        print('Size before removing loners: ' + str(len(full_df)))
        full_df = remove_loners(full_df)
        print('Size after removing loners: ' + str(len(full_df)))
    

    graph = nx.DiGraph()
    for i in range(0,len(full_df)):
        graph.add_edge(int(full_df.loc[i,"id_x"]), int(full_df.loc[i,'id_y']))
    
    for n in graph:
        graph.node[n]['node_name'] = nodes.loc[nodes['id'] == n, 'name'].to_string(index=False)
    
    #prepare for coloring the nodes according to if it is a match to a charity or not
    match_class_1 = full_df[['name_x', 'match_x']].rename(columns={'name_x':'name', 'match_x':'match'})
    match_class_2 = full_df[['name_y', 'match_y']].rename(columns={'name_y':'name', 'match_y':'match'})
    
    
    d = json_graph.node_link_data(graph)
    json.dump(d, open('network/force.json','w'))
    
    return graph

# %% [markdown]
# ### Graphing

# %%
graph = graph_leak_matches('panama', True)

graph
# Out:
#             0                                              1  Match
# 0    14014962                                            NaN  False
# 1    14022183                                            NaN  False
# 2    14050886                                            NaN  False
# 3    14063412                                            NaN  False
# 4    11000128                      PARKDALE INVESTMENTS S.A.  False
# 5    11000150                                   ICP SERVICES  False
# 6    11000269                              ZOLTY, LIC. ANDRE  False
# 7    11000382               HELENE MATHIEU LEGAL CONSULTANTS  False
# 8    11000402  (GENEVA CLIENT) SEMELY CONSEIL & GESTION S.A.  False
# 9    11000795                     OCTOPUS MANAGEMENT LIMITED  False
# 10   11000831                         STM FIDUCIAIRE LIMITED  False
# 11   11001520           EDUARDO RAMON ALEJANDRO FONSECA WARD  False
# 12   11001975              NAUTILUS FIDUCIARY  ASIA  LIMITED  False
# 13   11001994                        HAWKSFORD INTERNATIONAL  False
# 14   11002442             CENTURION MANAGEMENT SERVICES LTD.  False
# 15   11002790                         DAVID C. ALEXANDER III  False
# 16   11002845                   ORION TRUST (JERSEY) LIMITED  False
# 17   11003170                                CHERN HORNG JYN  False
# 18   11003237            NEW WORLD TRUSTEES (JERSEY) LIMITED  False
# 19   11003955                      ORION TRUST (JSY) LIMITED  False
# 20   11005398                       FIDUCIAIRE ROMAIN ZIMMER  False
# 21   11005424      CREDIT SUISSE  CHANNEL ISLANDS    LIMITED  False
# 22   11006258                             ANDREAS SCHULMEYER  False
# 23   11007207                         CLEARWATER INVESTMENTS  False
# 24   11009521         INTERNATIONAL MANAGEMENT LIMITED (IOM)  False
# 25   11009522           POPULAR CORPORATE SERVICE LIMITED #1  False
# 26   11010375                          JESSE H.Y. KWOK & CO.  False
# 27   11010460                                 BOND & COMPANY  False
# 28   11010583                      VAN VUUREN, ANTHONY JANSE  False
# 29   11010643              LEGAL CONSULTING SERVICES LIMITED  False
# ..        ...                                            ...    ...
# 81   10181757                       WORLD INTERNATIONAL LTD.   True
# 82   10181919                   CHRISTIAN INTERNATIONAL LTD.   True
# 83   10193267                      NEVE ZEDEK AL HAYAM CORP.  False
# 84   10211286           THE TRADEWINDS INVESTMENT FOUNDATION   True
# 85   10212007                           HIGH BECK FOUNDATION   True
# 86   10212191                  VANCOUVER PROPERTY FOUNDATION   True
# 87   10213350                                  ORRIS LIMITED  False
# 88   10213977                     HERITAGE GLOBAL FOUNDATION   True
# 89   12013331                                     THE BEARER  False
# 90   12048846                                    LI KA SHING   True
# 91   12057905                       THE STARLIGHT FOUNDATION   True
# 92   12096317                                     Kanis S.A.  False
# 93   12096931                             LARRY STUBBLEFIELD  False
# 94   12111264                                FORD FOUNDATION   True
# 95   12128743                                    LI KA SHING   True
# 96   12131024                                  GMG Trust Ltd  False
# 97   12131025                                 GMG Trust Ltd.  False
# 98   12146004                      VALINGER TRUSTEES LIMITED  False
# 99   12146005              Independent Guardian Trustees Ltd  False
# 100  12154650             Independent Guardian Trustees Ltd.  False
# 101  12161015                                     HUANG YING  False
# 102  12161016                                     WAN WAI ON  False
# 103  12164726                         AZTEC HOLDINGS LIMITED  False
# 104  12176209                  MEDIMEX INTERNATIONAL LIMITED  False
# 105  12180141                      HERITAGE VALUE FOUNDATION   True
# 106  12190239                  MEDIMEX INTERNATIONAL LIMITED  False
# 107  12197376                    CHRISTIAN INTERNATIONAL LTD   True
# 108  12220057                                        SMS LTD  False
# 109  12220058                                        GCS LTD  False
# 110  13002333                                         UNICEF   True
#
# [111 rows x 3 columns]

# %%
http_server.load_url('temp/force/index.html')
# Out:
# 127.0.0.1 - - [13/Dec/2018 10:17:09] code 404, message File not found
# 127.0.0.1 - - [13/Dec/2018 10:17:09] "GET /temp/force/index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Dec/2018 10:17:09] code 404, message File not found
# 127.0.0.1 - - [13/Dec/2018 10:17:09] "GET /favicon.ico HTTP/1.1" 404 -
# Press <RETURN> to stop server
#
# To restart server run:
# python -m http.server 8000

# %%
graph_leak_matches('paradise')
# Out:
# Matches for paradise papers:
# Name:
# Type: DiGraph
# Number of nodes: 467
# Number of edges: 376
# Average in degree:   0.8051
# Average out degree:   0.8051
#                                                 name_x match_x  id_x  \
# 0                      Appleby Services (Bermuda) Ltd.   False    95
# 1                                       Antoine - Dawn   False   261
# 2                                 Hodson - Kerri-Lynne   False   263
# 3                                         Dean - Donna   False   264
# 4                          Arthur Andersen - Singapore   False   265
# 5                                    Burns - Michael J   False   269
# 6                                 Counsell - Timothy J   False   271
# 7                                 Counsell - Timothy J   False   271
# 8                                Derby - Evaristo Sada   False   272
# 9                                         Diaz - Jaime   False   273
# 10                        Diez-Barroso - Javier Vargas   False   274
# 11                        Diez-Barroso - Javier Vargas   False   274
# 12                              Gil - Francisco Mateos   False   276
# 13                                      Lambe - Sumaya   False   282
# 14                                     Lee - Antoinett   False   283
# 15                  del Rio - Alvaro Corcuera Martínez   False   285
# 16                  del Rio - Alvaro Corcuera Martínez   False   285
# 17                                 Medina - Luis Garza   False   286
# 18                                 Medina - Luis Garza   False   286
# 19                                    Nazer - Cristian   False   287
# 20                                    Nazer - Cristian   False   287
# 21                                      Nurse - Tricia   False   289
# 22                           Pepper - Eduardo Vigneaux   False   290
# 23                           Pepper - Eduardo Vigneaux   False   290
# 24                          Pharoah-Williams - Deborah   False   291
# 25                                      Quirce - Jesus   False   293
# 26                                      Quirce - Jesus   False   293
# 27                         Sangiacomo - Mario Olivieri   False   295
# 28                         Sangiacomo - Mario Olivieri   False   295
# 29                   Herbert-Trott - Terrilynn Juanita   False   299
# ..                                                 ...     ...   ...
# 384                                     PIERRE SLADDEN   False   461
# 385  SOCIETY OF LADIES OF CHARITY OF ST. VINCENT DE...    True   453
# 386  SOCIETY OF LADIES OF CHARITY OF ST. VINCENT DE...    True   453
# 387                                 ANDREW DAVID NEAVE   False   454
# 388                                 ANDREW DAVID NEAVE   False   454
# 389                                 ANDREW DAVID NEAVE   False   454
# 390                                 ANDREW DAVID NEAVE   False   454
# 391                              PAUL ANTHONY O'CONNOR   False   465
# 392                              PAUL ANTHONY O'CONNOR   False   465
# 393                              PAUL ANTHONY O'CONNOR   False   465
# 394                              PAUL ANTHONY O'CONNOR   False   465
# 395                              PAUL ANTHONY O'CONNOR   False   465
# 396                           LIBRA PRIVATE FOUNDATION    True   455
# 397                           LIBRA PRIVATE FOUNDATION    True   455
# 398                                    ALEXANDER AGIUS   False   459
# 399                                     Antoine Cassar   False   460
# 400                                     Antoine Cassar   False   460
# 401                                     Antoine Cassar   False   460
# 402                                     Antoine Cassar   False   460
# 403                                     Antoine Cassar   False   460
# 404                                    LAWRENCE CASSAR   False   462
# 405                                    LAWRENCE CASSAR   False   462
# 406                                    LAWRENCE CASSAR   False   462
# 407                                    LAWRENCE CASSAR   False   462
# 408                                THE BUSH FOUNDATION    True   463
# 409                                THE BUSH FOUNDATION    True   463
# 410                                  ROBERT BOSCH GMBH    True   466
# 411                                  ROBERT BOSCH GMBH    True   466
# 412                                  ROBERT BOSCH GMBH    True   466
# 413                                  ROBERT BOSCH GMBH    True   466
#
#      START_ID    END_ID                                         name_y  \
# 0    80000191  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 1    80030223  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 2    80037268  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 3    80037286  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 4    80039411  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 5    80042906  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 6    80052824  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 7    80052824  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 8    80056334  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 9    80056818  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 10   80056954  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 11   80056954  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 12   80069716  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 13   80089836  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 14   80091456  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 15   80098769  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 16   80098769  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 17   80100853  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 18   80100853  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 19   80105858  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 20   80105858  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 21   80107777  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 22   80111646  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 23   80111646  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 24   80112319  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 25   80115239  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 26   80115239  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 27   80120804  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 28   80120804  82001786               INTERNATIONAL VOLUNTEER SERVICES
# 29   80137307  82001786               INTERNATIONAL VOLUNTEER SERVICES
# ..        ...       ...                                            ...
# 384  56045491  55087396                                            MAP
# 385  56006047  58040433            415 ST. CHRISTOPHER STREET VALLETTA
# 386  56006047  55003177                                    RTK LIMITED
# 387  56008914  55032526                                 ACUMEN LIMITED
# 388  56008914  55032526                                 ACUMEN LIMITED
# 389  56008914  55032526                                 ACUMEN LIMITED
# 390  56008914  55032526                                 ACUMEN LIMITED
# 391  56097173  55032526                                 ACUMEN LIMITED
# 392  56097173  55032526                                 ACUMEN LIMITED
# 393  56097173  55032526                                 ACUMEN LIMITED
# 394  56097173  55032526                                 ACUMEN LIMITED
# 395  56097173  55032526                                 ACUMEN LIMITED
# 396  56015006  58012914                         15, PIETERMAAI CURACAO
# 397  56015006  55066961                            FRONTSTREAM LIMITED
# 398  56023750  55048930                               Vision World Ltd
# 399  56043559  55048930                               Vision World Ltd
# 400  56043559  55048930                               Vision World Ltd
# 401  56043559  55048930                               Vision World Ltd
# 402  56043559  55048930                               Vision World Ltd
# 403  56043559  55048930                               Vision World Ltd
# 404  56044541  55048930                               Vision World Ltd
# 405  56044541  55048930                               Vision World Ltd
# 406  56044541  55048930                               Vision World Ltd
# 407  56044541  55048930                               Vision World Ltd
# 408  56040661  58034887  332, MINNESOTA ST. STE E-900 ST PAUL MN 55101
# 409  56040661  55029575                           TROY CAPITAL LIMITED
# 410  56095879  58072078               HEIDEHOFSTR 31, 70184, STUTTGART
# 411  56095879  55032964             ROBERT BOSCH HOLDING MALTA LIMITED
# 412  56095879  55051783        ROBERT BOSCH IC FINANCING MALTA LIMITED
# 413  56095879  55032967             ROBERT BOSCH FINANCE MALTA LIMITED
#
#     match_y  id_y
# 0      True   119
# 1      True   119
# 2      True   119
# 3      True   119
# 4      True   119
# 5      True   119
# 6      True   119
# 7      True   119
# 8      True   119
# 9      True   119
# 10     True   119
# 11     True   119
# 12     True   119
# 13     True   119
# 14     True   119
# 15     True   119
# 16     True   119
# 17     True   119
# 18     True   119
# 19     True   119
# 20     True   119
# 21     True   119
# 22     True   119
# 23     True   119
# 24     True   119
# 25     True   119
# 26     True   119
# 27     True   119
# 28     True   119
# 29     True   119
# ..      ...   ...
# 384    True   258
# 385   False    86
# 386   False   247
# 387    True   249
# 388    True   249
# 389    True   249
# 390    True   249
# 391    True   249
# 392    True   249
# 393    True   249
# 394    True   249
# 395    True   249
# 396   False    84
# 397   False   256
# 398    True   252
# 399    True   252
# 400    True   252
# 401    True   252
# 402    True   252
# 403    True   252
# 404    True   252
# 405    True   252
# 406    True   252
# 407    True   252
# 408   False    85
# 409   False   248
# 410   False    91
# 411   False   250
# 412   False   254
# 413   False   251
#
# [414 rows x 8 columns]

# %%
graph_leak_matches('offshore')
# Out:
# Matches for offshore papers:
# Name:
# Type: DiGraph
# Number of nodes: 68
# Number of edges: 58
# Average in degree:   0.8529
# Average out degree:   0.8529
#     node_id                                               name  match  id
# 0    237148                                                NaN  False   0
# 1    236724                                                NaN  False   1
# 2    264050                                                NaN  False   2
# 3    268974                                                NaN  False   3
# 4     49684                       Equity Trust (Samoa) Limited  False   4
# 5     54662                  Portcullis TrustNet (BVI) Limited  False   5
# 6    123290                Company Incorporations Asia Limited  False   6
# 7    119709                               ATC Primasia Limited  False   7
# 8    290197                          NetIncorp.com Corporation  False   8
# 9    291482       Gold-In Consulting Co., Ltd. ???????????????  False   9
# 10   296942                               Malkin & Maxwell LLP  False  10
# 11   297026  Wan-Shin Certified Public Accounting Firm - ??...  False  11
# 12   298073                               Hill Consulting Ltd.  False  12
# 13   147116                  INTERNATIONAL MEDICAL CORPORATION   True  13
# 14   158005               Vision World International Co., Ltd.   True  14
# 15   174703                       VISION INTERNATIONAL LIMITED   True  15
# 16   169213                            Friends of Assisi Trust  False  16
# 17   169289                  Herman Silver International Trust  False  17
# 18   158540                                 WORLD VISION CORP.   True  18
# 19   168995                            Captive Insurance Trust  False  19
# 20   197748              EAST MEETS WEST INTERNATIONAL LIMITED   True  20
# 21   208672                                       Adra Limited   True  21
# 22   158169                               WORLD VISION LIMITED   True  22
# 23   169460                                         Care Trust   True  23
# 24   170507                                  The Wexford Trust  False  24
# 25    72219                                        Wang, I-Lin  False  25
# 26   109972           World Vision                               True  26
# 27    87806                                      CHEN, Joan-Yi  False  27
# 28    92722                                    CHUNG, AI-CHING  False  28
# 29    90731                               CHENG CHEN, HUEY-WEN  False  29
# ..      ...                                                ...    ...  ..
# 38    81544                                    DANI ISMULYATIE  False  38
# 39    84445                                   CHEN, CHIN-CHUNG  False  39
# 40    94477                                    CHEN, LI-HSIANG  False  40
# 41    77721                                       CHUNG, AI-LI  False  41
# 42    79919                                     CHEN, HUNG-WEN  False  42
# 43   112458                                        CHEN, I-HAN  False  43
# 44    98828                                      CHEN, SHU-CHI  False  44
# 45   109057           Joan Ai-Lee Rombouts                      False  45
# 46    86009                                   YANG, SHIH-SHENG  False  46
# 47   102141           The Salvation Army                         True  47
# 48    96909                Portcullis TrustNet (Samoa) Limited  False  48
# 49   109710                      NetIncorp Agent Services Inc.  False  49
# 50   110052                                    CHEN, TAY-SHOUH  False  50
# 51   117408                           Alexander Johan Widjaja   False  51
# 52    20928               International Administrators Limited  False  52
# 53    22302                                  CIA Nominees Ltd.  False  53
# 54    22387                                          Sheng Bin  False  54
# 55    37736           Catholic Charities                         True  55
# 56    41975                             Angela Lestari Widjaja  False  56
# 57    42278           Vincent Yeoh Oon Weng                     False  57
# 58    67150                          MARIANELLA DOMADOR-PINEDA  False  58
# 59    49684                       Equity Trust (Samoa) Limited  False  59
# 60    53695                                    YANG, CHIH-HSIN  False  60
# 61    58528                                  HSUEH, CHING-YUEH  False  61
# 62    54662                  Portcullis TrustNet (BVI) Limited  False  62
# 63    53010                                       CHEN, LI-CHU  False  63
# 64    53149                                     YANG, TAI-YUAN  False  64
# 65    70068                                      WANG, YU-CHIN  False  65
# 66    73166                                      WU, MEI-LING   False  66
# 67    59567                                     YANG, CHIA-LUN  False  67
#
# [68 rows x 4 columns]

# %%
graph_leak_matches('bahamas')
# Out:
# Matches for bahamas papers:
# Name:
# Type: DiGraph
# Number of nodes: 45
# Number of edges: 27
# Average in degree:   0.6000
# Average out degree:   0.6000
#      node_id                                      name  match  id
# 0   23000046  ** DISABLED SUISSE SECURITY BANK & TRUST  False   0
# 1   23000047                             GRAHAM COOPER  False   1
# 2   23000083  PRICEWATERHOUSECOOPERS (BAHAMAS) LIMITED  False   2
# 3   23000136   MOSSACK FONSECA & CO. (BAHAMAS) LIMITED  False   3
# 4   23000139                FIRST CHOICE SERVICES LTD.  False   4
# 5   23000147               UBS TRUSTEES (BAHAMAS) LTD.  False   5
# 6   23000164                           MICHAEL HEPBURN  False   6
# 7   23000166                 SOVEREIGN BAHAMAS LIMITED  False   7
# 8   23000198         LENNOX CORPORATE SERVICES LIMITED  False   8
# 9   23000228             H & J CORPORATE SERVICES LTD.  False   9
# 10  23000238                           MCKINNEY TURNER  False  10
# 11  23000252                    DENNIS GOMEZ & COMPANY  False  11
# 12  23000280         PRIVATE TRUST CORPORATION LIMITED  False  12
# 13  23000294               RAS CORPORATE SERVICES LTD.  False  13
# 14  23000330               CREDIT SUISSE TRUST LIMITED  False  14
# 15  23000376      DOMINION MANAGEMENT SERVICES LIMITED  False  15
# 16  23000377                 OFFSHORE MANAGERS LIMITED  False  16
# 17  23000450                STERLING (BAHAMAS) LIMITED  False  17
# 18  20019717                 CROSS INTERNATIONAL CORP.   True  18
# 19  20043195                              ACUMEN CORP.   True  19
# 20  20045185              VISION INTERNATIONAL LIMITED   True  20
# 21  20063116                           CANTEEN LIMITED   True  21
# 22  20062102              CHRISTIAN INTERNATIONAL LTD.   True  22
# 23  20068610               LIONS INTERNATIONAL LIMITED   True  23
# 24  20072346             OPPORTUNITY INTERNATIONAL LTD   True  24
# 25  20081329                   EAST MEETS WEST LIMITED   True  25
# 26  20075548                       ACUMEN INCORPORATED   True  26
# 27  20077453                      CANCER RESEARCH CORP   True  27
# 28  20081853              THE HERITAGE FOUNDATION LTD.   True  28
# 29  20075969                                  CARE INC   True  29
# 30  20087962                        ACUMEN ENTERPRISES   True  30
# 31  20125485                             SANDY LIMITED   True  31
# 32  20126581                        United Way Limited   True  32
# 33  20098551                     MEDIA FOUNDATION LTD.   True  33
# 34  20099847               GOODWILL INTERNATIONAL LTD.   True  34
# 35  20101626                 INTERNATIONAL VISION LTD.   True  35
# 36  20103513                          YOUNG LIVES INC.   True  36
# 37  20118547                  WORLD INTERNATIONAL LTD.   True  37
# 38  21000216            The Lawrence Family Foundation   True  38
# 39  21000555               STARLIGHT GLOBAL FOUNDATION   True  39
# 40  22015372                         NOUH-CHAIA JOSEPH  False  40
# 41  22013223                        NOUH-CHAIA MONIQUE  False  41
# 42  22022615                        NOUH-CHAIA MONIQUE  False  42
# 43  22010304                          NOUH-CHAIA NAGIB  False  43
# 44  22007496                    NOUH-CHAIA-ISSA EVELYN  False  44

# %%
graph_leak_matches('panama', True)
# Out:
# Size before removing loners: 73
# Size after removing loners: 20
# Matches for panama papers:
# Name:
# Type: DiGraph
# Number of nodes: 22
# Number of edges: 18
# Average in degree:   0.8182
# Average out degree:   0.8182
#       node_id                                           name  match   id
# 0    14014962                                            NaN  False    0
# 1    14022183                                            NaN  False    1
# 2    14050886                                            NaN  False    2
# 3    14063412                                            NaN  False    3
# 4    11000128                      PARKDALE INVESTMENTS S.A.  False    4
# 5    11000150                                   ICP SERVICES  False    5
# 6    11000269                              ZOLTY, LIC. ANDRE  False    6
# 7    11000382               HELENE MATHIEU LEGAL CONSULTANTS  False    7
# 8    11000402  (GENEVA CLIENT) SEMELY CONSEIL & GESTION S.A.  False    8
# 9    11000795                     OCTOPUS MANAGEMENT LIMITED  False    9
# 10   11000831                         STM FIDUCIAIRE LIMITED  False   10
# 11   11001520           EDUARDO RAMON ALEJANDRO FONSECA WARD  False   11
# 12   11001975              NAUTILUS FIDUCIARY  ASIA  LIMITED  False   12
# 13   11001994                        HAWKSFORD INTERNATIONAL  False   13
# 14   11002442             CENTURION MANAGEMENT SERVICES LTD.  False   14
# 15   11002790                         DAVID C. ALEXANDER III  False   15
# 16   11002845                   ORION TRUST (JERSEY) LIMITED  False   16
# 17   11003170                                CHERN HORNG JYN  False   17
# 18   11003237            NEW WORLD TRUSTEES (JERSEY) LIMITED  False   18
# 19   11003955                      ORION TRUST (JSY) LIMITED  False   19
# 20   11005398                       FIDUCIAIRE ROMAIN ZIMMER  False   20
# 21   11005424      CREDIT SUISSE  CHANNEL ISLANDS    LIMITED  False   21
# 22   11006258                             ANDREAS SCHULMEYER  False   22
# 23   11007207                         CLEARWATER INVESTMENTS  False   23
# 24   11009521         INTERNATIONAL MANAGEMENT LIMITED (IOM)  False   24
# 25   11009522           POPULAR CORPORATE SERVICE LIMITED #1  False   25
# 26   11010375                          JESSE H.Y. KWOK & CO.  False   26
# 27   11010460                                 BOND & COMPANY  False   27
# 28   11010583                      VAN VUUREN, ANTHONY JANSE  False   28
# 29   11010643              LEGAL CONSULTING SERVICES LIMITED  False   29
# ..        ...                                            ...    ...  ...
# 81   10181757                       WORLD INTERNATIONAL LTD.   True   81
# 82   10181919                   CHRISTIAN INTERNATIONAL LTD.   True   82
# 83   10193267                      NEVE ZEDEK AL HAYAM CORP.  False   83
# 84   10211286           THE TRADEWINDS INVESTMENT FOUNDATION   True   84
# 85   10212007                           HIGH BECK FOUNDATION   True   85
# 86   10212191                  VANCOUVER PROPERTY FOUNDATION   True   86
# 87   10213350                                  ORRIS LIMITED  False   87
# 88   10213977                     HERITAGE GLOBAL FOUNDATION   True   88
# 89   12013331                                     THE BEARER  False   89
# 90   12048846                                    LI KA SHING   True   90
# 91   12057905                       THE STARLIGHT FOUNDATION   True   91
# 92   12096317                                     Kanis S.A.  False   92
# 93   12096931                             LARRY STUBBLEFIELD  False   93
# 94   12111264                                FORD FOUNDATION   True   94
# 95   12128743                                    LI KA SHING   True   95
# 96   12131024                                  GMG Trust Ltd  False   96
# 97   12131025                                 GMG Trust Ltd.  False   97
# 98   12146004                      VALINGER TRUSTEES LIMITED  False   98
# 99   12146005              Independent Guardian Trustees Ltd  False   99
# 100  12154650             Independent Guardian Trustees Ltd.  False  100
# 101  12161015                                     HUANG YING  False  101
# 102  12161016                                     WAN WAI ON  False  102
# 103  12164726                         AZTEC HOLDINGS LIMITED  False  103
# 104  12176209                  MEDIMEX INTERNATIONAL LIMITED  False  104
# 105  12180141                      HERITAGE VALUE FOUNDATION   True  105
# 106  12190239                  MEDIMEX INTERNATIONAL LIMITED  False  106
# 107  12197376                    CHRISTIAN INTERNATIONAL LTD   True  107
# 108  12220057                                        SMS LTD  False  108
# 109  12220058                                        GCS LTD  False  109
# 110  13002333                                         UNICEF   True  110
#
# [111 rows x 4 columns]

# %%
graph_leak_matches('paradise', True)
# Out:
# Size before removing loners: 414
# Size after removing loners: 122
# Matches for paradise papers:
# Name:
# Type: DiGraph
# Number of nodes: 94
# Number of edges: 84
# Average in degree:   0.8936
# Average out degree:   0.8936
#        node_id                                               name  match   id
# 0     81021085  405 Lexington Avenue, Third Floor; New York Ne...  False    0
# 1     81024524  One Rotary Center; 1560 Sherman Avenue; Evanst...  False    1
# 2     81026273  3rd Floor, 2431 – 37 Ave NE; Calgary T2E 3A8; ...  False    2
# 3     81027090  Canon's Court; 22 Victoria Street; Hamilton; H...  False    3
# 4     81027146  Clifton House; 75 Fort Street; Grand Cayman KY...  False    4
# 5     81029389  Argyle House; 41a Cedar Avenue; Hamilton HM 12...  False    5
# 6     81031545         46 Point Finger Road; Paget DV 04; Bermuda  False    6
# 7     81032909  225 N Michigan; Suite 1200; Chicago; IL 60601;...  False    7
# 8     81035645  One Robert Wood Johnson Place; New Brunswick; ...  False    8
# 9     81037035  633 Third Avenue, 4th Floor; New York; New Yor...  False    9
# 10    81038750  P O Box 520; Colorado Springs 80901; CO; Unite...  False   10
# 11    81041199  7th Floor, Cheung Kong Center; 2 Queen's Road ...  False   11
# 12    81042682  800 W Chestnut Ave., M/#704; Monrovia; CA 9101...  False   12
# 13    81046581  320 East 43rd Street; New York; N.Y. 10017; Un...  False   13
# 14    81048039  c/o David Becker; 2200 South Dakota Avenue; Wa...  False   14
# 15    81050475  400 Jones Bridge Road; Chevy Chase; MD 20815; ...  False   15
# 16    81052034  1200 Getty Center Drive; Suite 300; 90049 Los ...  False   16
# 17    81053473  3125 W Big Beaver Road; Troy MI  48084; United...  False   17
# 18    81062913  Box 2316, College Road East & Route One; Princ...  False   18
# 19    81065295             32 Valley Road; Paget   PG 05; Bermuda  False   19
# 20    81067179  4245 North Fairfax Drive, Suite 100; Arlington...  False   20
# 21    81067219  Route 1 and College Road East; Princeton; New ...  False   21
# 22    81073298  99-119 Rosebery Avenue; EC1R 4RE London; Unite...  False   22
# 23    81073545           89 St. Saviour's Road; St Helier; Jersey  False   23
# 24    81076933  1000 Fifth Avenue; New York   NY10028-0198; Un...  False   24
# 25    81081201  c/o Treasury Services; 200 First Street SW; Ro...  False   25
# 26    81081627  Wilberforce Way; Southwater; Horsham; West Sus...  False   26
# 27    81084646  c/o Sonnedix UK Services Limited; 57 Great Suf...  False   27
# 28    81000811          Heiligkreuz 6; Vaduz; 9490; Liechtenstein  False   28
# 29    81003805                  79 Deep Water Bay Road; Hong Kong  False   29
# ..         ...                                                ...    ...  ...
# 437  110118202                 COLYBRAND COMPANY SERVICES LIMITED  False  437
# 438  110003325                                   ST. JOHN JEAN A.  False  438
# 439  110111855                                    MARTINDALE ANNE  False  439
# 440  110112011                                        DUVAL MARIO  False  440
# 441  110095771                                    BLANDFORD SUSAN  False  441
# 442  110098344                                    MAPP ABU AKIL L  False  442
# 443  110123510                                  WEEKES W. WILLIAM  False  443
# 444  110127656                               FITZGERALD THOMAS J.  False  444
# 445  110110514                                    SAWHILL JOHN C.  False  445
# 446  110039443                                   LANDIS WILLIAM A  False  446
# 447  110098915                                 ST. JOHN ANDREW N.  False  447
# 448  210000063                                       ROMAN GERSAK  False  448
# 449  210000068                                     PREVOST JULIEN  False  449
# 450  210000196                                      LEVICAR DUSAN  False  450
# 451   56032075                         MEHEMMED IZZIDIN BEK DERNA  False  451
# 452   56026651                                      AARON SLADDEN  False  452
# 453   56006047  SOCIETY OF LADIES OF CHARITY OF ST. VINCENT DE...   True  453
# 454   56008914                                 ANDREW DAVID NEAVE  False  454
# 455   56015006                           LIBRA PRIVATE FOUNDATION   True  455
# 456   56037732                                     MARVIC SLADDEN  False  456
# 457   56033327                            ADEL MEHEMMED BEK DERNA  False  457
# 458   56033328                    ADEL MEHEMMED IZZIDIN BEK DERNA  False  458
# 459   56023750                                    ALEXANDER AGIUS  False  459
# 460   56043559                                     Antoine Cassar  False  460
# 461   56045491                                     PIERRE SLADDEN  False  461
# 462   56044541                                    LAWRENCE CASSAR  False  462
# 463   56040661                                THE BUSH FOUNDATION   True  463
# 464   56072038                DFK (Malta) Farrugia, Farrugia & Co  False  464
# 465   56097173                              PAUL ANTHONY O'CONNOR  False  465
# 466   56095879                                  ROBERT BOSCH GMBH   True  466
#
# [467 rows x 4 columns]

# %%
graph_leak_matches('offshore', True)
# Out:
# Size before removing loners: 68
# Size after removing loners: 23
# Matches for offshore papers:
# Name:
# Type: DiGraph
# Number of nodes: 17
# Number of edges: 13
# Average in degree:   0.7647
# Average out degree:   0.7647
#     node_id                                               name  match  id
# 0    237148                                                NaN  False   0
# 1    236724                                                NaN  False   1
# 2    264050                                                NaN  False   2
# 3    268974                                                NaN  False   3
# 4     49684                       Equity Trust (Samoa) Limited  False   4
# 5     54662                  Portcullis TrustNet (BVI) Limited  False   5
# 6    123290                Company Incorporations Asia Limited  False   6
# 7    119709                               ATC Primasia Limited  False   7
# 8    290197                          NetIncorp.com Corporation  False   8
# 9    291482       Gold-In Consulting Co., Ltd. ???????????????  False   9
# 10   296942                               Malkin & Maxwell LLP  False  10
# 11   297026  Wan-Shin Certified Public Accounting Firm - ??...  False  11
# 12   298073                               Hill Consulting Ltd.  False  12
# 13   147116                  INTERNATIONAL MEDICAL CORPORATION   True  13
# 14   158005               Vision World International Co., Ltd.   True  14
# 15   174703                       VISION INTERNATIONAL LIMITED   True  15
# 16   169213                            Friends of Assisi Trust  False  16
# 17   169289                  Herman Silver International Trust  False  17
# 18   158540                                 WORLD VISION CORP.   True  18
# 19   168995                            Captive Insurance Trust  False  19
# 20   197748              EAST MEETS WEST INTERNATIONAL LIMITED   True  20
# 21   208672                                       Adra Limited   True  21
# 22   158169                               WORLD VISION LIMITED   True  22
# 23   169460                                         Care Trust   True  23
# 24   170507                                  The Wexford Trust  False  24
# 25    72219                                        Wang, I-Lin  False  25
# 26   109972           World Vision                               True  26
# 27    87806                                      CHEN, Joan-Yi  False  27
# 28    92722                                    CHUNG, AI-CHING  False  28
# 29    90731                               CHENG CHEN, HUEY-WEN  False  29
# ..      ...                                                ...    ...  ..
# 38    81544                                    DANI ISMULYATIE  False  38
# 39    84445                                   CHEN, CHIN-CHUNG  False  39
# 40    94477                                    CHEN, LI-HSIANG  False  40
# 41    77721                                       CHUNG, AI-LI  False  41
# 42    79919                                     CHEN, HUNG-WEN  False  42
# 43   112458                                        CHEN, I-HAN  False  43
# 44    98828                                      CHEN, SHU-CHI  False  44
# 45   109057           Joan Ai-Lee Rombouts                      False  45
# 46    86009                                   YANG, SHIH-SHENG  False  46
# 47   102141           The Salvation Army                         True  47
# 48    96909                Portcullis TrustNet (Samoa) Limited  False  48
# 49   109710                      NetIncorp Agent Services Inc.  False  49
# 50   110052                                    CHEN, TAY-SHOUH  False  50
# 51   117408                           Alexander Johan Widjaja   False  51
# 52    20928               International Administrators Limited  False  52
# 53    22302                                  CIA Nominees Ltd.  False  53
# 54    22387                                          Sheng Bin  False  54
# 55    37736           Catholic Charities                         True  55
# 56    41975                             Angela Lestari Widjaja  False  56
# 57    42278           Vincent Yeoh Oon Weng                     False  57
# 58    67150                          MARIANELLA DOMADOR-PINEDA  False  58
# 59    49684                       Equity Trust (Samoa) Limited  False  59
# 60    53695                                    YANG, CHIH-HSIN  False  60
# 61    58528                                  HSUEH, CHING-YUEH  False  61
# 62    54662                  Portcullis TrustNet (BVI) Limited  False  62
# 63    53010                                       CHEN, LI-CHU  False  63
# 64    53149                                     YANG, TAI-YUAN  False  64
# 65    70068                                      WANG, YU-CHIN  False  65
# 66    73166                                      WU, MEI-LING   False  66
# 67    59567                                     YANG, CHIA-LUN  False  67
#
# [68 rows x 4 columns]

# %%
graph_leak_matches('bahamas', True)
# Out:
# Size before removing loners: 27
# Size after removing loners: 7
# Matches for bahamas papers:
# Name:
# Type: DiGraph
# Number of nodes: 10
# Number of edges: 7
# Average in degree:   0.7000
# Average out degree:   0.7000
#      node_id                                      name  match  id
# 0   23000046  ** DISABLED SUISSE SECURITY BANK & TRUST  False   0
# 1   23000047                             GRAHAM COOPER  False   1
# 2   23000083  PRICEWATERHOUSECOOPERS (BAHAMAS) LIMITED  False   2
# 3   23000136   MOSSACK FONSECA & CO. (BAHAMAS) LIMITED  False   3
# 4   23000139                FIRST CHOICE SERVICES LTD.  False   4
# 5   23000147               UBS TRUSTEES (BAHAMAS) LTD.  False   5
# 6   23000164                           MICHAEL HEPBURN  False   6
# 7   23000166                 SOVEREIGN BAHAMAS LIMITED  False   7
# 8   23000198         LENNOX CORPORATE SERVICES LIMITED  False   8
# 9   23000228             H & J CORPORATE SERVICES LTD.  False   9
# 10  23000238                           MCKINNEY TURNER  False  10
# 11  23000252                    DENNIS GOMEZ & COMPANY  False  11
# 12  23000280         PRIVATE TRUST CORPORATION LIMITED  False  12
# 13  23000294               RAS CORPORATE SERVICES LTD.  False  13
# 14  23000330               CREDIT SUISSE TRUST LIMITED  False  14
# 15  23000376      DOMINION MANAGEMENT SERVICES LIMITED  False  15
# 16  23000377                 OFFSHORE MANAGERS LIMITED  False  16
# 17  23000450                STERLING (BAHAMAS) LIMITED  False  17
# 18  20019717                 CROSS INTERNATIONAL CORP.   True  18
# 19  20043195                              ACUMEN CORP.   True  19
# 20  20045185              VISION INTERNATIONAL LIMITED   True  20
# 21  20063116                           CANTEEN LIMITED   True  21
# 22  20062102              CHRISTIAN INTERNATIONAL LTD.   True  22
# 23  20068610               LIONS INTERNATIONAL LIMITED   True  23
# 24  20072346             OPPORTUNITY INTERNATIONAL LTD   True  24
# 25  20081329                   EAST MEETS WEST LIMITED   True  25
# 26  20075548                       ACUMEN INCORPORATED   True  26
# 27  20077453                      CANCER RESEARCH CORP   True  27
# 28  20081853              THE HERITAGE FOUNDATION LTD.   True  28
# 29  20075969                                  CARE INC   True  29
# 30  20087962                        ACUMEN ENTERPRISES   True  30
# 31  20125485                             SANDY LIMITED   True  31
# 32  20126581                        United Way Limited   True  32
# 33  20098551                     MEDIA FOUNDATION LTD.   True  33
# 34  20099847               GOODWILL INTERNATIONAL LTD.   True  34
# 35  20101626                 INTERNATIONAL VISION LTD.   True  35
# 36  20103513                          YOUNG LIVES INC.   True  36
# 37  20118547                  WORLD INTERNATIONAL LTD.   True  37
# 38  21000216            The Lawrence Family Foundation   True  38
# 39  21000555               STARLIGHT GLOBAL FOUNDATION   True  39
# 40  22015372                         NOUH-CHAIA JOSEPH  False  40
# 41  22013223                        NOUH-CHAIA MONIQUE  False  41
# 42  22022615                        NOUH-CHAIA MONIQUE  False  42
# 43  22010304                          NOUH-CHAIA NAGIB  False  43
# 44  22007496                    NOUH-CHAIA-ISSA EVELYN  False  44
