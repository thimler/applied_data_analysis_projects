# %%
# Imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import math
import re
import numpy as np

# %%
DATA_FOLDER = 'data'

# %%
# Loading and creation of dataframes
pp_edges = pd.read_csv('data' + '/panama_papers.edges.csv', sep=',')
pp_adress = pd.read_csv('data' + '/panama_papers.nodes.address.csv', sep=',')
pp_entity = pd.read_csv('data' + '/panama_papers.nodes.entity.csv', sep=',')
pp_intermediary = pd.read_csv('data' + '/panama_papers.nodes.intermediary.csv', sep=',')
pp_officer = pd.read_csv('data' + '/panama_papers.nodes.officer.csv', sep=',')
# Out:
# C:\Users\Lucas\Anaconda3\envs\ada\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Lucas\Anaconda3\envs\ada\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pp_officer
# Out:
#          node_id                                               name  \
# 0       12000001                                         KIM SOO IN
# 1       12000002                                          Tian Yuan
# 2       12000003                               GREGORY JOHN SOLOMON
# 3       12000004                                     MATSUDA MASUMI
# 4       12000005                                        HO THUY NGA
# 5       12000006                                     RACHMAT ARIFIN
# 6       12000007                                        TAN SUN-HUA
# 7       12000008                      Ou Yang Yet-Sing and Chang Ko
# 8       12000009                  Wu Chi-Ping and Wu Chou Tsan-Ting
# 9       12000010                                      ZHONG LI MING
# 10      12000011                                           LIN PING
# 11      12000012                                 BOSHEN LTD./135-77
# 12      12000013                                 BOSHEN LTD./133-58
# ...
